# %% [markdown]
# # Рынок общепита
#
# - Автор: Козбаков Айдын
# - Дата: 23.02.2026г.

# %% [markdown]
# ### Цели и задачи проекта
#
# Основная цель проекта - провести исследовательский анализ рынка общепита г. Москва

# %% [markdown]
# ### Описание данных
#
# Файл `/datasets/rest_info.csv` содержит информацию о заведениях общественного питания:
#
# - `name` — название заведения;
# - `address` — адрес заведения;
# - `district` — административный район, в котором находится заведение, например Центральный административный округ;
# - `category` — категория заведения, например «кафе», «пиццерия» или «кофейня»;
# - `hours` — информация о днях и часах работы;
# - `rating` — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — `5.0`);
# - `chain` — число, выраженное `0` или `1`, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
#     - `0` — заведение не является сетевым;
#     - `1` — заведение является сетевым.
# - `seats` — количество посадочных мест.
#
# Файл `/datasets/rest_price.csv` содержит информацию о среднем чеке в заведениях общественного питания:
#
# - `price` — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
# - `avg_bill` — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#     - «Средний счёт: 1000–1500 ₽»;
#     - «Цена чашки капучино: 130–220 ₽»;
#     - «Цена бокала пива: 400–600 ₽».
#         и так далее;
# - `middle_avg_bill` — число с оценкой среднего чека, которое указано только для значений из столбца `avg_bill`, начинающихся с подстроки «Средний счёт»:
#     - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#     - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#     - Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
# - `middle_coffee_cup` — число с оценкой одной чашки капучино, которое указано только для значений из столбца `avg_bill`, начинающихся с подстроки «Цена одной чашки капучино»:
#     - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#     - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#     - Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.

# %% [markdown]
# ### Содержимое проекта
#
# # **Шаг 1. Загрузка данных и знакомство с ними**
#
# 1. Загрузите данные о заведениях общественного питания Москвы. Путь к файлам: `/datasets/rest_info.csv` и `/datasets/rest_price.csv`.
# 2. Познакомьтесь с данными и изучите общую информацию о них.
# 3. Сделайте вывод о полученных данных: каков объём данных, соответствуют ли данные описанию, встречаются ли пропущенные значения, используются ли верные типы данных.
# 4. Отметьте другие особенности данных, которые вы обнаружите на этой стадии и на которые стоит обратить внимание при предобработке.
# 5. Объедините данные двух датасетов в один, с которым вы и продолжите работу.
#
# # **Шаг 2. Предобработка данных**
#
# Подготовьте данные к исследовательскому анализу:
#
# 1. Изучите корректность типов данных и при необходимости проведите их преобразование. Помните, что наличие пропусков в данных может влиять на их тип.
# 2. Изучите пропущенные значения в данных: посчитайте их количество в каждом столбце датафрейма, изучите данные с пропущенными значениями и предположите гипотезы их появления. Проведите обработку пропущенных значений: вы можете заменить пропуски на определённое значение, удалить строки с пропусками или оставить их как есть.
# 3. Проверьте данные на явные и неявные дубликаты, например, поля с названием и адресом заведения. Для оптимизации проверки нормализуйте данные в текстовых столбцах, например с названием заведения.
# 4. Для дальнейшей работы выделите новые столбцы:
#     - Создайте столбец `is_24_7` с обозначением того, что заведение работает ежедневно и круглосуточно, то есть 24/7:
#         - логическое значение `True` — если заведение работает ежедневно и круглосуточно;
#         - логическое значение `False` — в противоположном случае.
#
# После предобработки данных напишите промежуточный вывод о проведённой работе. Отразите количество или долю отфильтрованных данных, если вы что-то удаляли.
#
# # **Шаг 3. Исследовательский анализ данных**
#
# Проведите исследовательский анализ исходных данных и ответьте на вопросы:
#
# 1. Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по каждой категории. Результат сопроводите подходящей визуализацией.
# 2. Какие административные районы Москвы присутствуют в данных? Исследуйте распределение количества заведений по административным районам Москвы, а также отдельно распределение заведений каждой категории в Центральном административном округе Москвы. Результат сопроводите подходящими визуализациями.
# 3. Изучите соотношение сетевых и несетевых заведений в целом по всем данным и в разрезе категорий заведения. Каких заведений больше — сетевых или несетевых? Какие категории заведений чаще являются сетевыми? Исследуйте данные, ответьте на вопросы и постройте необходимые визуализации.
# 4. Исследуйте количество посадочных мест в заведениях. Встречаются ли в данных аномальные значения или выбросы? Если да, то с чем они могут быть связаны? Приведите для каждой категории заведений наиболее типичное для него количество посадочных мест. Результат сопроводите подходящими визуализациями.
# 5. Исследуйте рейтинг заведений. Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги для разных типов общепита?
# 6. Изучите, с какими данными показывают самую сильную корреляцию рейтинги заведений? Постройте и визуализируйте матрицу корреляции рейтинга заведения с разными данными: его категория, положение (административный район Москвы), статус сетевого заведения, количество мест, ценовая категория и признак, является ли заведения круглосуточным. Выберите самую сильную связь и проверьте её.
# 7. Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Для них посчитайте значения среднего рейтинга. Под популярностью понимается количество заведений этой сети в регионе. К какой категории заведений они относятся? Результат сопроводите подходящими визуализациями.
# 8. Изучите вариацию среднего чека заведения (столбец `middle_avg_bill`) в зависимости от района Москвы. Проанализируйте цены в центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях? Результат сопроводите подходящими визуализациями.
#
# При исследовании данных используйте визуализации. Проверьте, что для каждого случая был подобран оптимальный тип визуализации с корректным оформлением. У графика должен быть заголовок, понятные подписи по осям, при необходимости легенда, а его размер является оптимальным для изучения.
#
# После исследования каждого пункта оставляйте небольшой комментарий с выводом или обсуждением результата. В конце шага обобщите результаты, выделив, по вашему мнению, самые важные.
#
# # **Шаг 4. Итоговый вывод и рекомендации**
#
# По результатам проведённого исследовательского анализа данных сформулируйте итоговый вывод и рекомендации для заказчика. Старайтесь акцентировать внимание на ключевых моментах исследования.
#
# При составлении вывода придерживайтесь такой структуры:
#
# 1.     Общий обзор проделанной работы.
#
# 2.     Ответы на исследовательские вопросы, или главные выводы.
#
# 3.     Рекомендации на основе анализа данных.

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите данные о заведениях общественного питания Москвы. Путь к файлам: `/datasets/rest_info.csv` и `/datasets/rest_price.csv`.

# %%
# Импортируем библиотеки
import pandas as pd

# Загружаем библиотеки для визуализации данных
import matplotlib.pyplot as plt
import seaborn as sns

# Загружаем библиотеку для расчёта коэффициента корреляции phi_k
from phik import phik_matrix

# %%
try:
    info_df = pd.read_csv('/datasets/rest_info.csv')
    price_df = pd.read_csv('/datasets/rest_price.csv')
except FileNotFoundError:
    info_df = pd.read_csv('rest_info.csv', index_col=0)
    price_df = pd.read_csv('rest_price.csv', index_col=0)

# %%
info_df.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats
# ...

# %%
info_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        8406 non-null   str
#  1   name      8406 non-null   str
#  2   category  8406 non-null   str
#  3   address   8406 non-null   str
#  4   district  8406 non-null   str
#  5   hours     7870 non-null   str
#  6   rating    8406 non-null   float64
#  7   chain     8406 non-null   int64
#  8   seats     4795 non-null   float64
# dtypes: float64(2), int64(1), str(6)
# memory usage: 591.2 KB

# %%
price_df.head()
# Out:
#                                  id          price  \
# 0  045780ada3474c57a2112e505d74b633  выше среднего
# 1  1070b6b59144425896c65889347fcff6        средние
# 2  03ac7cd772104f65b58b349dc59f03ee            NaN
# 3  a163aada139c4c7f87b0b1c0b466a50f        средние
# 4  8a343546b24e4a499ad96eb7d0797a8a        средние
#
#                         avg_bill  middle_avg_bill  middle_coffee_cup
# 0       Средний счёт:1500–1600 ₽           1550.0                NaN
# 1         Средний счёт:от 1000 ₽           1000.0                NaN
# 2  Цена чашки капучино:155–185 ₽              NaN              170.0
# 3         Средний счёт:400–600 ₽            500.0                NaN
# 4                            NaN              NaN                NaN

# %%
price_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4058 entries, 0 to 4057
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4058 non-null   str
#  1   price              3315 non-null   str
#  2   avg_bill           3816 non-null   str
#  3   middle_avg_bill    3149 non-null   float64
#  4   middle_coffee_cup  535 non-null    float64
# dtypes: float64(2), str(3)
# memory usage: 158.6 KB

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# Сделайте промежуточный вывод о полученных данных: данные какого объёма вам предоставили, соответствуют ли данные описанию, встречаются ли в них пропуски, используются ли верные типы данных. Отметьте другие особенности данных, которые вы обнаружите на этой стадии и на которые стоит обратить внимание при предобработке.

# %% [markdown]
# Датасет `rest_infoo.csv` содержит 8 столбцов и 8406 строк, в которых представлена информация об заведениях общественного питания г. Москва.
#
# После первичного анализа данных можно сделать следующие выводы:
# - Значения в столбцах `id`, `name`, `category`, `address`, `district` и `hours` представлены строковыми данными 'str'. 'chain' показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки), можно оптимизировать этот тип.
# - Пропуски содержатся только в столбцах `hours` и 'seats'. Однако следует проверить и другие столбцы: в них могут встречаться значения-индикаторы, которые будут говорить об отсутствии данных.
# - Судя по первому знакомству с данными, значения в столбцах соответствуют своему описанию.
#
# Теперь познакомимся с данными датасета `rest_pricee.csv`.

# %% [markdown]
# Датасет `rest_pricee.csv` содержит 9 столбцов и 4058 строк, в которых представлена информация о среднем чеке в заведениях общественного питания.
#
# После первичного анализа данных можно сделать следующие выводы:
# - Значения в столбцах `id`, `price`, `avg_bill` представлены строковыми данными 'str'. `middle_avg_bill` и `middle_coffee_cup` представлены числовыми данными 'float'
# - Пропуски содержатся во всех столбцах кроме `id`. Скорее всего просто не для всех заведений имеются данные о ценах
# - Судя по первому знакомству с данными, значения в столбцах соответствуют своему описанию.

# %% [markdown]
# ### Подготовка единого датафрейма
#
# - Объедините данные двух датасетов в один, с которым вы и продолжите работу.

# %%
df = info_df.merge(price_df,on='id',how='left')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   str
#  1   name               8406 non-null   str
#  2   category           8406 non-null   str
#  3   address            8406 non-null   str
#  4   district           8406 non-null   str
#  5   hours              7870 non-null   str
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   float64
#  9   price              3315 non-null   str
#  10  avg_bill           3816 non-null   str
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: float64(4), int64(1), str(8)
# memory usage: 853.9 KB

# %%
df.head()
# Out:
#                                  id                  name  category  \
# 0  0c3e3439a8c64ea5bf6ecd6ca6ae19f0                WoWфли      кафе
# 1  045780ada3474c57a2112e505d74b633        Четыре комнаты  ресторан
# 2  1070b6b59144425896c65889347fcff6                 Хазри      кафе
# 3  03ac7cd772104f65b58b349dc59f03ee  Dormouse Coffee Shop   кофейня
# 4  a163aada139c4c7f87b0b1c0b466a50f             Иль Марко  пиццерия
#
#                                address                         district  \
# 0           Москва, улица Дыбенко, 7/1  Северный административный округ
# 1   Москва, улица Дыбенко, 36, корп. 1  Северный административный округ
# 2       Москва, Клязьминская улица, 15  Северный административный округ
# 3  Москва, улица Маршала Федоренко, 12  Северный административный округ
# 4      Москва, Правобережная улица, 1Б  Северный административный округ
#
#                                                hours  rating  chain  seats  \
# ...

# %%
temp = df.copy() 
len(temp)
# Out:
# 8406

# %% [markdown]
# ## 2. Предобработка данных
#
# Подготовьте данные к исследовательскому анализу:
#
# - Изучите корректность типов данных и при необходимости проведите их преобразование.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8406 non-null   str
#  1   name               8406 non-null   str
#  2   category           8406 non-null   str
#  3   address            8406 non-null   str
#  4   district           8406 non-null   str
#  5   hours              7870 non-null   str
#  6   rating             8406 non-null   float64
#  7   chain              8406 non-null   int64
#  8   seats              4795 non-null   float64
#  9   price              3315 non-null   str
#  10  avg_bill           3816 non-null   str
#  11  middle_avg_bill    3149 non-null   float64
#  12  middle_coffee_cup  535 non-null    float64
# dtypes: float64(4), int64(1), str(8)
# memory usage: 853.9 KB

# %%
# Оптимизируем типы данных в датафрейме
# Сначала для целочисленного столбца chain
df['chain'] = pd.to_numeric(df['chain'], downcast='integer')

# Теперь для остальных числовых столбцов по вашему совету
for column in ['rating', 'middle_avg_bill', 'middle_coffee_cup', 'seats']:
    df[column] = pd.to_numeric(df[column], downcast='float')

# Применил рекомендацию по оптимизации разрядности данных для экономии памяти.

# %% [markdown]
# - Изучите пропущенные значения в данных: посчитайте их количество в каждом столбце датафрейме, изучите данные с пропущенными значениями и предположите гипотезы их появления. Проведите обработку пропущенных значений: вы можете заменить пропуски на определённое значение, удалить строки с пропусками или оставить их как есть.

# %%
# Абсолютное кол-во пропусков
df.isna().sum()
# Out:
# id                      0
# name                    0
# category                0
# address                 0
# district                0
# hours                 536
# rating                  0
# chain                   0
# seats                3611
# price                5091
# avg_bill             4590
# middle_avg_bill      5257
# middle_coffee_cup    7871
# dtype: int64

# %%
# Относительное кол-во пропусков
round(df.isna().sum()/len(df),2)*100
# Out:
# id                    0.0
# name                  0.0
# category              0.0
# address               0.0
# district              0.0
# hours                 6.0
# rating                0.0
# chain                 0.0
# seats                43.0
# price                61.0
# avg_bill             55.0
# middle_avg_bill      63.0
# middle_coffee_cup    94.0
# dtype: float64

# %%
# Комментарий ревьюера
def show_missing_stats(tmp0):
    """
    Функция для отображения статистики пропущенных значений в DataFrame.
    """
    missing_stats = pd.DataFrame({
        'Кол-во пропусков': tmp0.isnull().sum(),
        'Доля пропусков': tmp0.isnull().mean()
    })
    missing_stats = missing_stats[missing_stats['Кол-во пропусков'] > 0]
    
    if missing_stats.empty:
        return "Пропусков в данных нет"
    
    # Форматируем при выводе через Styler
    return (missing_stats.style.format({'Доля пропусков': '{:.4f}'}).background_gradient(cmap='coolwarm'))
show_missing_stats(df)
# Out:
# <style type="text/css">
# #T_fdc77_row0_col0, #T_fdc77_row0_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fdc77_row1_col0, #T_fdc77_row1_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_fdc77_row2_col0, #T_fdc77_row2_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_fdc77_row3_col0, #T_fdc77_row3_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_fdc77_row4_col0, #T_fdc77_row4_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_fdc77_row5_col0, #T_fdc77_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fdc77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdc77_level0_col0" class="col_heading level0 col0" >Кол-во пропусков</th>
#       <th id="T_fdc77_level0_col1" class="col_heading level0 col1" >Доля пропусков</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Столбцы middle_avg_bill и middle_coffee_cup - скорее всего пропуски из-за человеческого фактора либо специфика сбора данных, не все заведения предоставляют информацию о среднем чеке, некоторые бары, пабы не указывают цену за чашку кофе так как для них это не актуально. Оставим как есть Nan так как удалять мы не можем

# %% [markdown]
# Столбец rating - заведение может быть новым и не успело накопить отзывы. Удалять тоже не можем, так как потеряем информацию о заведениях

# %% [markdown]
# Можно заметить большое кол-во пропусков в seats(многие заведения могут работать только на вынос?)

# %% [markdown]
# - Проверьте данные на явные и неявные дубликаты, например поля с названием и адресом заведения. Для оптимизации проверки нормализуйте данные в текстовых столбцах, например с названием заведения.

# %%
# Проверка полных дубликатов
print(f"Количество полных дубликатов: {df.duplicated().sum()}")
# Out:
# Количество полных дубликатов: 0

# %%
# Приведем названия заведений и адреса к нижнему регистру
df['name'] = df['name'].str.lower().str.strip()
df['address'] = df['address'].str.lower().str.strip()

# %%
df['name'].value_counts()
# Out:
# name
# кафе                   189
# шоколадница            120
# домино'с пицца          77
# додо пицца              74
# one price coffee        72
#                       ...
# пекарня, кафе-гриль      1
# суши мания               1
# миславнес                1
# самовар                  1
# kebab time               1
# Name: count, Length: 5512, dtype: int64

# %%
# так как в нашем датасете имеются сети заведений, то при подсчете одинаковые названия сетей будут считаться дубликатами
# нам нужно посчитать дубликаты по столбцам name и address
df.duplicated(subset = ['name','address']).sum()
# Out:
# np.int64(4)

# %%
# Показываем строки, которые являются дубликатами по названию и адресу
duplicates = df[df.duplicated(subset=['name', 'address'])]
display(duplicates.head())
# Out:
#                                     id                       name  category  \
# 215   897ddbc6746c4388b19dc8a9fcdbb488                       кафе      кафе
# 1511  a69f018d5c064873a3b491b0121bc1b4                  more poke  ресторан
# 2420  aba1de7ad7d64ac0a3f8684bda29d905  раковарня клешни и хвосты   бар,паб
# 3109  d3116844e4e048f99614eb30be3214e0            хлеб да выпечка      кафе
#
#                                       address  \
# 215              москва, парк ангарские пруды
# 1511  москва, волоколамское шоссе, 11, стр. 2
# 2420               москва, проспект мира, 118
# 3109              москва, ярцевская улица, 19
#
#                                      district  \
# 215           Северный административный округ
# 1511          Северный административный округ
# 2420  Северо-Восточный административный округ
# 3109          Западный административный округ
#
#                                                   hours  rating  chain  seats  \
# ...

# %%
# 4 полных дубликата можно удалить
df = df.drop_duplicates(subset=['name', 'address'])

# %% [markdown]
# - Для дальнейшей работы создайте столбец `is_24_7` с обозначением того, что заведение работает ежедневно и круглосуточно, то есть 24/7:
#   - логическое значение `True` — если заведение работает ежедневно и круглосуточно;
#   - логическое значение `False` — в противоположном случае.

# %%
df['is_24_7'] = df['hours'].str.contains('ежедневно, круглосуточно',na=False,case=False)

# %%
df['is_24_7'].value_counts()
# Out:
# is_24_7
# False    7672
# True      730
# Name: count, dtype: int64

# %% [markdown]
# 730 заведений работает ежедневно и круглосуточно

# %%
# Комментарий ревьюера
# Проверим сколько удалено строк датасета
a, b = len(temp), len(df)
print(" Было строк в исходном датасете", a,
      '\n', "Осталось строк в датасете после обработки", b,
      '\n', "Удалено строк в датасете после обработки", a-b,
      '\n', "Процент потерь", round((a-b)/a*100, 2))
# Out:
#  Было строк в исходном датасете 8406
#  Осталось строк в датасете после обработки 8402
#  Удалено строк в датасете после обработки 4
#  Процент потерь 0.05

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# После предобработки данных напишите промежуточный вывод о проведённой работе. Отразите количество или долю отфильтрованных данных, если вы что-то удаляли.

# %% [markdown]
# Мы провели предобработку данных:
# - Удалили ненужные столбцы Unnamed 0
# - Соединили два датасета по идентификатору заведения, оставив все данные из левой таблицы
# - Оптимизировали столбец 'chain' в int8, чтобы данные работали быстрее
# - Привели названия заведений и адреса в нижний регистр
# - Нашли явные и неявные дубликаты и удалили их (4 штуки)
# - Создали новый столбец 'is_24_7' куда вошли 730 заведений

# %% [markdown]
# ## 3. Исследовательский анализ данных
# Проведите исследовательский анализ исходных данных.
#
# При исследовании данных используйте визуализации. Проверьте, что для каждого случая подобран оптимальный тип визуализации с корректным оформлением. У графика должен быть заголовок, понятные подписи по осям, при необходимости легенда, а его размер является оптимальным для изучения.
#
# После исследования каждого пункта оставляйте небольшой комментарий с выводом или обсуждением результата. В конце шага обобщите результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# ---
#
# ### Задача 1
#
# Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по каждой категории. Результат сопроводите подходящей визуализацией.

# %%
df['category'].value_counts()
# Out:
# category
# кафе               2376
# ресторан           2042
# кофейня            1413
# бар,паб             764
# пиццерия            633
# быстрое питание     603
# столовая            315
# булочная            256
# Name: count, dtype: int64

# %%
df['category'].value_counts(normalize=True)
# Out:
# category
# кафе               0.282790
# ресторан           0.243037
# кофейня            0.168174
# бар,паб            0.090931
# пиццерия           0.075339
# быстрое питание    0.071769
# столовая           0.037491
# булочная           0.030469
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))
df['category'].value_counts().plot(kind='bar',
                title='Категории заведений',
                legend=False,
                ylabel='Количество заведений',
                xlabel='Категория',
                rot=45)
plt.show()

# %% [markdown]
# Лидеры рынка: Рынок общественного питания Москвы сильно смещен в сторону формата кафе, которые занимают доминирующую долю в 28%. Вместе с форматами «ресторан» и «кофейня» они формируют костяк рынка (более 60% всех объектов).
#
# Сравнение: Количество кафе почти в 3 раза превышает количество заведений фастфуда, что говорит о том что люди предпочитают более спокойную культуру заведений чем еду на быструю еду на вынос
#
# Аутсайдеры: Самый низкий показатель у столовых и магазинов-кулинарий. Это может свидетельствовать либо о низком спросе на такие форматы, либо о «голубом океане» — свободной нише для бюджетного питания.
#
# Бизнес-смысл: Высокая концентрация кафе означает экстремально высокую конкуренцию. Для нового игрока выход в эту категорию будет самым сложным и потребует уникального предложения.
#
# Рекомендация: Если цель — быстрый захват доли рынка с минимальными рисками, стоит рассмотреть формат кофейни или пиццерии, так как они показывают стабильный рост, но рынок в этих сегментах еще не так перенасыщен, как в категории стандартных кафе.

# %% [markdown]
# ---
#
# ### Задача 2
#
# Какие административные районы Москвы присутствуют в данных? Исследуйте распределение количества заведений по административным районам Москвы, а также отдельно распределение заведений каждой категории в Центральном административном округе Москвы. Результат сопроводите подходящими визуализациями.

# %%
df['district'].value_counts()
# Out:
# district
# Центральный административный округ         2242
# Северный административный округ             898
# Южный административный округ                892
# Северо-Восточный административный округ     890
# Западный административный округ             850
# Восточный административный округ            798
# Юго-Восточный административный округ        714
# Юго-Западный административный округ         709
# Северо-Западный административный округ      409
# Name: count, dtype: int64

# %%
df['district'].value_counts(normalize=True)
# Out:
# district
# Центральный административный округ         0.266841
# Северный административный округ            0.106879
# Южный административный округ               0.106165
# Северо-Восточный административный округ    0.105927
# Западный административный округ            0.101166
# Восточный административный округ           0.094977
# Юго-Восточный административный округ       0.084980
# Юго-Западный административный округ        0.084385
# Северо-Западный административный округ     0.048679
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(14, 6))
df['district'].value_counts(ascending=True).plot(kind='barh',
				title='Количество заведений в каждом адм. районе Москвы',
                legend=False,
                ylabel='Адм. район',
                xlabel='Количество заведений',
				rot=0)
plt.show()

# %% [markdown]
# Можно заметить, что основное колиечство заведений приходится на ЦАО (27%), в то время как минимальное количество заведений в СЗАО (около 5 %)

# %%
cao_data = df[df['district'] == 'Центральный административный округ']
cao_data.groupby('category')['category'].count().sort_values(ascending=False)
# Out:
# category
# ресторан           670
# кафе               464
# кофейня            428
# бар,паб            364
# пиццерия           113
# быстрое питание     87
# столовая            66
# булочная            50
# Name: category, dtype: int64

# %%
cao_data['category'].value_counts(normalize=True)
# Out:
# category
# ресторан           0.298840
# кафе               0.206958
# кофейня            0.190901
# бар,паб            0.162355
# пиццерия           0.050401
# быстрое питание    0.038805
# столовая           0.029438
# булочная           0.022302
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(14, 6))
cao_data.groupby('category')['category'].count().sort_values(ascending=True).plot(kind='barh',
				title='Количество заведений в Центральном адм. округе',
                legend=False,
                ylabel='Заведения',
                xlabel='Количество заведений',
				rot=0)
plt.show()

# %% [markdown]
# По данной визуализации можно сделать вывод, что в ЦАО на первом месте по популярности стоят рестораны (30%). Далее идут кафе и кофейни (20 %). наименее популярные заведения быстрое питаение, столовые и булочные (менее 4 %). Это может сказать нам о том что в данной локации посетители предпочитают более премиальные сегменты питания

# %% [markdown]
# ---
#
# ### Задача 3
#
# Изучите соотношение сетевых и несетевых заведений в целом по всем данным и в разрезе категорий заведения. Каких заведений больше — сетевых или несетевых? Какие категории заведений чаще являются сетевыми? Исследуйте данные, ответьте на вопросы и постройте необходимые визуализации.

# %%
# Кол-во сетевых и несетевых заведений
print(f'''Кол-во сетевых заведений: {df['chain'].sum()}''')
print(f'''Кол-во несетевых заведений: {len(df) - df['chain'].sum()}''')

# Соотношение сетевых заведений
print(f'''Соотношение сетевых заведений от общего числа: {round(df['chain'].sum() / len(df),2)}''')
# Out:
# Кол-во сетевых заведений: 3203
# Кол-во несетевых заведений: 5199
# Соотношение сетевых заведений от общего числа: 0.38

# %%
plt.figure(figsize=(10, 6))
df['chain'].value_counts(normalize=True).plot(kind='bar',
				title='Количество сетевых и несетевых заведений',
                legend=False,
                ylabel='Количество заведений',
                xlabel='Сетевое заведение',
				rot=0)
plt.show()

# %%
# Кол-во заведений в разрезе категорий заведения
df.groupby('category')['chain'].value_counts().unstack(fill_value=0)
# Out:
# chain               0    1
# category
# бар,паб           596  168
# булочная           99  157
# быстрое питание   371  232
# кафе             1597  779
# кофейня           693  720
# пиццерия          303  330
# ресторан         1313  729
# столовая          227   88

# %%
df.groupby('category')['chain'].value_counts(ascending=True).unstack(fill_value=0).plot(kind='bar',
				title='Количество сетевых и несетевых заведений',
                legend=True,
                ylabel='Категория заведения',
                xlabel='Количество заведений',
				rot=0,
                figsize=(12,6))
plt.show()

# %% [markdown]
# - Кол-во сетевых заведений (3203) меньше чем несетевых (5199)
# - Сетевые заведения составляют 38% от общего числа
# - Популярность сетевых заведений хорошо видна на количестве кофеен, булочных и пиццерий, их число превышает кол-во несетевых заведений

# %% [markdown]
# ---
#
# ### Задача 4
#
# Исследуйте количество посадочных мест в заведениях. Встречаются ли в данных аномальные значения или выбросы? Если да, то с чем они могут быть связаны? Приведите для каждой категории заведений наиболее типичное для него количество посадочных мест. Результат сопроводите подходящими визуализациями.

# %%
df['seats'].describe()
# Out:
# count    4792.000000
# mean      108.361435
# std       122.841133
# min         0.000000
# 25%        40.000000
# 50%        75.000000
# 75%       140.000000
# max      1288.000000
# Name: seats, dtype: float64

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(data=df, x='seats', y='category')
plt.title('Распределение количества посадочных мест по категориям', fontsize=16)
plt.xlabel('Количество мест')
plt.ylabel('Категория')
plt.show()

# %% [markdown]
# Можно отметить большое количество выбросов у всех категорий заведений

# %%
df.groupby('category')['seats'].describe()
# Out:
#                   count        mean         std  min   25%   50%    75%  \
# category
# бар,паб           467.0  124.477516  145.162277  0.0  48.0  82.0  148.5
# булочная          148.0   89.385132   97.685844  0.0  25.0  50.0  120.0
# быстрое питание   349.0   98.891121  106.611740  0.0  28.0  65.0  140.0
# кафе             1217.0   97.365654  117.922462  0.0  35.0  60.0  120.0
# кофейня           751.0  111.199730  127.837776  0.0  40.0  80.0  144.0
# пиццерия          427.0   94.496490  112.282700  0.0  30.0  55.0  120.0
# ресторан         1269.0  121.892044  123.792213  0.0  48.0  86.0  150.0
# столовая          164.0   99.750000  122.951454  0.0  40.0  75.5  117.0
#
#                     max
# category
# бар,паб          1288.0
# булочная          625.0
# быстрое питание  1040.0
# кафе             1288.0
# кофейня          1288.0
# пиццерия         1288.0
# ресторан         1288.0
# столовая         1200.0

# %% [markdown]
# - маловероятно, что у заведений имеется более 1000 посадочных мест, это говорит об ошибке
# - можно отметить что среднее и медиана у некоторых категорий значительно отличается, что говорит о выбросах
# - минимальные значения 0 говорят о том что заведения работают на доставку?
# - чтобы посчитать наиболее типичное количество посадочных мест, будем использовать медиану

# %%
# Группируем по категории и считаем медиану
typical_seats = df.groupby('category')['seats'].median().sort_values(ascending=True)
typical_seats
# Out:
# category
# булочная           50.0
# пиццерия           55.0
# кафе               60.0
# быстрое питание    65.0
# столовая           75.5
# кофейня            80.0
# бар,паб            82.0
# ресторан           86.0
# Name: seats, dtype: float32

# %%
typical_seats.plot.barh(title='типичное количество посадочных мест',
                       ylabel='заведение',
                       xlabel='количество мест')
plt.show()

# %% [markdown]
# Исследуйте количество посадочных мест в заведениях. Встречаются ли в данных аномальные значения или выбросы? Если да, то с чем они могут быть связаны? Приведите для каждой категории заведений наиболее типичное для него количество посадочных мест. Результат сопроводите подходящими визуализациями.
# 1. Почти во всех завдениях встречается анмоальное количество посадочных мест (больше 1000) кроме булочных
# 2. Могут быть связаны с выбросами, либо имеются заведения для скопления большого количества людей

# %% [markdown]
# ---
#
# ### Задача 5
#
# Исследуйте рейтинг заведений. Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги для разных типов общепита?

# %%
df['rating'].describe()
# Out:
# count    8402.000000
# mean        4.230017
# std         0.470320
# min         1.000000
# 25%         4.100000
# 50%         4.300000
# 75%         4.400000
# max         5.000000
# Name: rating, dtype: float64

# %%
# Посчитаем средний рейтинг категорий заведений
category_ratings = df.groupby('category')['rating'].mean().sort_values(ascending=True)
category_ratings
# Out:
# category
# быстрое питание    4.050249
# кафе               4.124284
# столовая           4.211429
# булочная           4.268359
# кофейня            4.277282
# ресторан           4.290401
# пиццерия           4.301264
# бар,паб            4.387696
# Name: rating, dtype: float32

# %%
# Применяем describe к сгруппированным данным
category_stats = df.groupby('category')['rating'].describe()
display(category_stats)
# Out:
#                   count      mean       std  min  25%  50%  75%  max
# category
# бар,паб           764.0  4.387697  0.380392  1.1  4.3  4.4  4.6  5.0
# булочная          256.0  4.268360  0.386303  1.3  4.2  4.3  4.4  5.0
# быстрое питание   603.0  4.050249  0.560949  1.1  3.9  4.2  4.3  5.0
# кафе             2376.0  4.124284  0.566001  1.0  4.0  4.2  4.4  5.0
# кофейня          1413.0  4.277282  0.372250  1.4  4.1  4.3  4.4  5.0
# пиццерия          633.0  4.301264  0.336162  1.0  4.2  4.3  4.4  5.0
# ресторан         2042.0  4.290401  0.413143  1.0  4.2  4.3  4.5  5.0
# столовая          315.0  4.211429  0.454205  1.0  4.1  4.3  4.4  5.0

# %%
category_ratings.plot.barh(title='Средний рейтинг по категориям заведений',
                          xlabel='Рейтинг',
                          ylabel='Заведения')
plt.show()

# %% [markdown]
# Средние оценки по категориям заведений не отличаются сильно, диапазон 4.05-4.39. Максимальное у баров, пабов (4.39), минимальное у быстрого питания (4.05)
# может быть связано что посетители баров более в веселом настроении и оставляют более высокие оценки, в то время как у быстрого питания большой поток посетитилей, после которых не всегда успевают следить за чистотой и сервисом

# %% [markdown]
# ---
#
# ### Задача 6
#
# Изучите, с какими данными показывают самую сильную корреляцию рейтинги заведений? Постройте и визуализируйте матрицу корреляции рейтинга заведения с разными данными: его категория, положение (административный район Москвы), статус сетевого заведения, количество мест, ценовая категория и признак, является ли заведения круглосуточным. Выберите самую сильную связь и проверьте её.

# %%
phik_columns = ['rating', 'category', 'district', 'chain', 'seats', 'price', 'is_24_7']

# Считаем матрицу phik
phik_correlations = df[phik_columns].phik_matrix()

# Рисуем Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(phik_correlations, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Матрица корреляции Phi_k (учитывает категории)')
plt.show()
# Out:
# interval columns not set, guessing: ['rating', 'chain', 'seats']

# %% [markdown]
# Можно отметить, что высокая корреляция наблюдается у категории заведения и ценой (0.57), количеством мест и локацией (0.35), категорий и является ли заведение сетевым (0.27)

# %% [markdown]
# Самая сильная связь с рейтингом наблюдается у:
# - цены заведения (0.22) - более дорогие заведения уделяют качеству сервиса, еды, атмосферы больше внимания, вследствии люди ставят выше рейтинг
# - локации (0.20) - местоположение влияет на цену, это мы узнаем ниже при сравнении цен округов
# - категория заведения (0.19) - рейтинги у столовых отличаются от рейтингов ресторанов

# %%
df.groupby('price')['rating'].mean()
# Out:
# price
# высокие          4.436611
# выше среднего    4.386347
# низкие           4.173077
# средние          4.297874
# Name: rating, dtype: float32

# %%
df.groupby('price')['rating'].mean().sort_values().plot.bar(xlabel='Ценовая категория заведения', 
                                              ylabel='Оценки');

# %%
df.groupby('district')['rating'].mean().sort_values(ascending=False)
# Out:
# district
# Центральный административный округ         4.377520
# Северный административный округ            4.240980
# Северо-Западный административный округ     4.208802
# Южный административный округ               4.184417
# Западный административный округ            4.181647
# Восточный административный округ           4.174185
# Юго-Западный административный округ        4.172920
# Северо-Восточный административный округ    4.147977
# Юго-Восточный административный округ       4.101120
# Name: rating, dtype: float32

# %% [markdown]
# в ЦАО рейтинг самый высокий 4.37

# %%
df.groupby('category')['rating'].mean().sort_values(ascending=False)
# Out:
# category
# бар,паб            4.387696
# пиццерия           4.301264
# ресторан           4.290401
# кофейня            4.277282
# булочная           4.268359
# столовая           4.211429
# кафе               4.124284
# быстрое питание    4.050249
# Name: rating, dtype: float32

# %% [markdown]
# здесь видна разница среднего рейтинга у "дешевых заведений" - 4.17 и у "дорогих" - 4.43
# может быть связано, что более дорогие заведения больше уделяют внимание качеству сервиса, блюд и чистоте, в то время как дешевые нет

# %% [markdown]
# ---
#
# ### Задача 7
#
# Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Для них посчитайте значения среднего рейтинга. Под популярностью понимается количество заведений этой сети в регионе. К какой категории заведений они относятся? Результат сопроводите подходящими визуализациями.

# %%
# Фильтруем только сетевые заведения
chains = df[df['chain'] == 1]

# Группируем одновременно по названию и по категории
top_15_chains = (
    chains.groupby(['name', 'category'])
    .agg(
        number=('id', 'count'),
        avg_rating=('rating', 'mean')
    )
    .sort_values(by='number', ascending=False)
    .head(15)
    .reset_index()
)

# Выводим результат
display(top_15_chains)
# Out:
#                                    name  category  number  avg_rating
# 0                           шоколадница   кофейня     119    4.178151
# 1                        домино'с пицца  пиццерия      76    4.169737
# 2                            додо пицца  пиццерия      74    4.286487
# 3                      one price coffee   кофейня      71    4.064789
# 4                          яндекс лавка  ресторан      69    3.872464
# 5                                 cofix   кофейня      65    4.075385
# 6                                 prime  ресторан      49    4.114285
# 7                              кофепорт   кофейня      42    4.147619
# 8   кулинарная лавка братьев караваевых      кафе      39    4.394872
# 9                               теремок  ресторан      36    4.105556
# 10                             cofefest   кофейня      31    3.977419
# 11                              чайхана      кафе      26    3.946154
# ...

# %%
# Комментарий ревьюера
tmp = df.copy()          # создаем копию текущего датасета
name_tmp = 'му-му'       # задаем имя столбца для проверки уникальных категорий
print(f'Заведения с одинаковым именем {name_tmp} относятся к разным категориям:\n\
{", ".join(tmp[tmp.name == name_tmp].category.unique())}')
# Out:
# Заведения с одинаковым именем му-му относятся к разным категориям:
# кафе, ресторан, кофейня, быстрое питание, пиццерия, столовая, бар,паб

# %%
top_15_chains.sort_values(by='number',ascending=True).plot(kind='barh', 
                                                                     x='name', 
                                                                     y='number',
                                                                     title='Топ 15 популярных сетей в Москве по количеству')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %%
top_15_chains.sort_values(by='avg_rating',ascending=True).plot(kind='barh', 
                                                                     x='name', 
                                                                     y='avg_rating',
                                                                     title='Топ 15 популярных сетей в Москве по среднему рейтингу')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# В топ-15 ожидаемо доминируют гиганты фастфуда (KFC, Burger King, Вкусно — и точка) и кофейни (Шоколадница, Cofix). Это подтверждает, что сетевая модель в Москве наиболее эффективна в сегментах с высокой скоростью обслуживания и стандартизированным меню.

# %% [markdown]
# ---
#
# ### Задача 8
#
# Изучите вариацию среднего чека заведения (столбец `middle_avg_bill`) в зависимости от района Москвы. Проанализируйте цены в Центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях? Результат сопроводите подходящими визуализациями.

# %%
df['middle_avg_bill'].describe()
# Out:
# count     3149.000000
# mean       958.053650
# std       1009.732849
# min          0.000000
# 25%        375.000000
# 50%        750.000000
# 75%       1250.000000
# max      35000.000000
# Name: middle_avg_bill, dtype: float64

# %%
df.plot.hist(y='middle_avg_bill', bins=50, figsize=(10, 6), title='Распределение среднего чека')
plt.xlabel('Средний чек (руб.)')
plt.ylabel('Количество заведений')
plt.show()

# %%
sns.boxplot(data=df, x='middle_avg_bill', color='skyblue')

plt.title('Диаграмма размаха для среднего чека (Boxplot)')
plt.xlabel('Средний чек (руб.)')

plt.show()

# %%
avg_price=df.groupby('district')['middle_avg_bill'].describe().sort_values(by='mean',ascending=True)
avg_price
# Out:
#                                           count         mean          std  \
# district
# Юго-Восточный административный округ      194.0   654.097961   566.825684
# Северо-Восточный административный округ   301.0   716.611267   591.232178
# Юго-Западный административный округ       235.0   792.561707   559.173157
# Восточный административный округ          260.0   820.626953   850.903320
# Северо-Западный административный округ    157.0   822.222900   595.055237
# Южный административный округ              314.0   834.398071  2008.640625
# Северный административный округ           322.0   927.959656   912.609192
# Западный административный округ           306.0  1053.225464   779.008545
# Центральный административный округ       1060.0  1191.057495   920.014709
#
#                                            min     25%     50%     75%  \
# district
# Юго-Восточный административный округ      30.0  281.25   450.0   887.5
# ...

# %%
avg_price['mean'].plot(kind='barh',
                      x='district',
                      y='mean',
                      title='Средний чек заведения по округам Москвы',
                      xlabel='Средний чек',
                      ylabel='Округ')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Анализ распределения стоимости по географии Москвы:
#
# Лидеры по стоимости (Максимальный чек): Самый высокий средний чек ожидаемо зафиксирован в Центральном административном округе (ЦАО) — около 1200 руб., а также в Западном округе (ЗАО). ЦАО является центром деловой активности и туризма с самой дорогой стоимостью аренды. Здесь сосредоточены премиальные рестораны и заведения «не для всех», что сильно завышает среднюю планку. ЗАО также считается престижным районом с высоким уровнем дохода жителей.
#
# Наиболее «стабильными» и однородными по цене являются ЮЗАО и СЗАО.
# На диаграмме размаха в этих округах практически отсутствуют «выбросы». Это говорит о том, что рынок там представлен в основном сетевым масс-маркетом и бюджетными локальными кафе. Там нет (или крайне мало) сверхдорогих концептуальных ресторанов, которые могли бы исказить статистику.
#
# Минимальные значения чека:
# Самые низкие показатели среднего чека наблюдаются в Юго-Восточном (ЮВАО) и Южном (ЮАО) округах — около 650–750 руб.
# Это традиционно «спальные» и индустриальные районы Москвы. Потребитель здесь ориентирован на быстрый перекус или семейный обед по доступной цене. Для бизнеса это означает, что открывать здесь премиальное заведение крайне рискованно — аудитория может быть не готова к высокому чеку.
#
# Разрыв в среднем чеке между центром и периферией составляет почти 2 раза. При планировании инвестиций заказчику нужно понимать: в ЦАО мы платим за статус и получаем доступ к «дорогому» клиенту, а в ЮВАО — работаем на обороте и массовости, удерживая низкую цену.

# %% [markdown]
# ---
#
# ### Промежуточный вывод
#
# Обобщите полученные результаты, выделив, по вашему мнению, самые важные.

# %% [markdown]
# - **Кафе** самое популярное заведение 2376 штук, столовые и булочные наименее популярные 315 и 256
# - Наблюдается наибольшая концентрация бизнеса в **ЦАО** (2 242 объекта), что в 5.5 раз превышает количество заведений в **СЗАО** (409 объектов).
# - В **ЦАО** структура предложения смещена в сторону **ресторанов** (670), в то время как социальные форматы (столовые и булочные) представлены минимально (66 и 50 объектов соответственно).
# - Сетевые заведения составляют примерно **38%** - 3203 штуки, несетевые - 5199
# - В среднем в **ресторанах** больше всего посадочных мест - 86, меньше всего в булочных - 50
# - Самое популярное сетевое заведение  **кофейня “Шоколадница”** 120 штук со средним рейтингом 4.17
# - Наиболее высокий средний чек в **Центральном адм. округе** 1191, наименьший в в Юго-Восточном адм. округе 654 руб.

# %% [markdown]
# **Самая сильная связь с рейтингом наблюдается у**:
# - цены заведения (0.22) - более дорогие заведения уделяют качеству сервиса, еды, атмосферы больше внимания, вследствии люди ставят выше рейтинг
# - локации (0.20) - местоположение влияет на цену, это мы узнаем ниже при сравнении цен округов
# - категория заведения (0.19) - рейтинги у столовых отличаются от рейтингов ресторанов

# %% [markdown]
# ## 4. Итоговый вывод и рекомендации
#
# По результатам проведённого исследовательского анализа данных сформулируйте итоговый вывод и рекомендации для заказчика. Старайтесь акцентировать внимание на ключевых моментах исследования.
#
# При составлении вывода придерживайтесь такой структуры:
#
# 1. Общий обзор проделанной работы.
# 2. Ответы на исследовательские вопросы, или главные выводы.
# 3. Рекомендации на основе анализа данных.

# %% [markdown]
# ### Общий обзор проделанной работы
# - Объем выборки - 8402 уникальных объекта
# - Данные прошли полную предобработку (удаление дубликатов, ненужных полей, обработка пропусков, проведения типов)

# %% [markdown]
# ### Главные выводы
#
# - Кафе являются самым массовым сегментом (2 376 объектов), в то время как узкоспециализированные булочные и столовые занимают менее 5% рынка.
# - ЦАО концентрирует в себе четверть всех заведений города (2 242). При этом структура центра смещена в сторону ресторанов высокого ценового сегмента. СЗАО, напротив, является наименее насыщенным районом (409 объектов).
# - Сети занимают 38% рынка. Наиболее успешно сетевая модель реализуется в кофейнях и пиццериях. Крупнейший игрок — «Шоколадница» (120 точек) — задает стандарт среднего рейтинга на уровне 4.17.
# - Установлено, что статистически значимым фактором, влияющим на рейтинг, является ценовая категория, локация, категория заведения. Заведения с высоким чеком имеют средний рейтинг 4.43, что значительно выше бюджетного сегмента (4.17), чем ближе к центру, темы выше рейтинг, бары, пиццерии и рестораны имеют больше рейтинг чем быстрое питание
# - Средний чек в ЦАО (1 191 руб.) почти вдвое превышает чек в ЮВАО (654 руб.), что отражает разную покупательную способность и структуру спроса.

# %% [markdown]
# ### Рекомендации для заказчика
# На основе полученных данных для открытия нового успешного заведения рекомендуются следующие шаги:
#
# **Выбор формата**: Оптимальным вариантом будет авторский (несетевой) **ресторан** или **кафе**. Отсутствие привязки к сети позволит создать уникальную атмосферу, что ценится в высококонкурентных районах.
#
# **Ценовая политика**: Рекомендуется ориентироваться на ценовой сегмент **«выше среднего»**. Данные показывают, что именно такие заведения чаще получают высокие оценки от пользователей, что обеспечит приток новых гостей через органический поиск в картах.
#
# **Локация**: * Вариант А (Премиальный): Центральный административный округ. Плюсы: максимальный чек и спрос. Риски: экстремальная конкуренция.
#
# Вариант Б (Развивающийся): Западный административный округ (ЗАО). Он показывает вторую по величине доходность, но имеет меньшую плотность заведений по сравнению с центром.
#
# **Вместимость**: Рекомендуемое количество посадочных мест — от 70 до 90. Это медианное значение для успешных ресторанов Москвы, позволяющее эффективно использовать площадь и обеспечивать окупаемость.
#
# **Дополнительные услуги**: Несмотря на слабую корреляцию с общим рейтингом, наличие круглосуточного режима работы может стать преимуществом в районах с высокой деловой активностью (ЦАО), где зафиксирован дефицит таких мест.
